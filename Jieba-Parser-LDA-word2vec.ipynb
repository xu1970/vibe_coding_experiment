# %%
import re
import jieba.posseg as pseg
from functions import *

# %%
import emoji

# %%
import pandas as pd

# %%
import stanza
CORENLP_SERVER_URL = 'http://localhost:9000'
client = stanza.Pipeline('zh', tokenize_pretokenized=True, processors='tokenize, pos,lemma, depparse')
# Out:
# 2025-04-09 20:34:42 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2025-04-09 20:34:44 INFO: Downloaded file to /Users/xiangningxu/stanza_resources/resources.json
# 2025-04-09 20:34:44 INFO: "zh" is an alias for "zh-hans"
# 2025-04-09 20:34:47 INFO: Loading these models for language: zh-hans (Simplified_Chinese):
# ================================
# | Processor | Package          |
# --------------------------------
# | tokenize  | gsdsimp          |
# | pos       | gsdsimp_charlm   |
# | lemma     | gsdsimp_nocharlm |
# | depparse  | gsdsimp_charlm   |
# ================================
#
# 2025-04-09 20:34:47 INFO: Using device: cpu
# 2025-04-09 20:34:47 INFO: Loading: tokenize
# 2025-04-09 20:34:47 INFO: Loading: pos
# 2025-04-09 20:34:49 INFO: Loading: lemma
# 2025-04-09 20:34:49 INFO: Loading: depparse
# 2025-04-09 20:34:49 INFO: Done loading processors!

# %%
def parse_dependencies(text):
    """
    Parse dependencies using Stanford CoreNLP for Chinese.
    """
    if not text.strip():
        return None
    doc = client(text)
    dependencies = []
    for sentence in doc.sentences:
        for word in sentence.words:
            dependencies.append({
                "word": word.text,
                "head": word.head,  # Index of the head word (0 if root)
                "relation": word.deprel,  # Dependency relation
                "governor": sentence.words[word.head - 1].text if word.head > 0 else "ROOT"
            })
    return dependencies

# %%
custom_words_file = 'custom_words.txt'
add_words_from_file(custom_words_file)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/13/k9tvrh6d47bcwm8lgp_tklmw0000gn/T/jieba.cache
# Loading model cost 0.728 seconds.
# Prefix dict has been built successfully.

# %%
def tokenize(text):
    tokens = [word.word for word in pseg.cut(text)]#if word.flag!='m'
    return ' '.join(tokens)

# %%
def convert_emoji(sentence):
    sentence = emoji.demojize(sentence)
    sentence = re.sub(r":cow_face::horse_face:", "牛马", sentence)
    sentence = re.sub(r'\[[^\[\]]*\]','', sentence)
    return sentence

# %%
def preprocess(sentence):
    #remove @ or 回复@ handle
    sentence = re.sub(r'回复|[\u4e00-\u9fff]@[^:]*:','', sentence)
    sentence = re.sub('@[^:]* ','', sentence)
    
    sentence = re.sub(r'[\s]', '，',sentence)
    sentence = re.sub(r'[\n\t\s]*', '', sentence)
    sentence = re.sub(r'我觉得', '',sentence)
    sentence = re.sub(r'[“+”（）]','', sentence)
    sentence = re.sub(r'%','百分之', sentence)
    return sentence

# %%
def split2chunks(sentence):
    chunks = re.split(r'[。！？?，, （）\[\];:、……]', sentence) #split by punctuations
    chunks = [chunk.strip() for chunk in chunks if chunk.strip()] #remove any empties
    chunks = [chunk for chunk in chunks if len(chunk)>2]
    return chunks

# %% [markdown]
# sentence = "对于孩子，我有义务给他一个健康快乐的童年，而不是和我一样充满压抑和对未来都是恐惧的童年。但是，我清楚的知道我目前没用这个能力，也没这个底气，我对未来一直都是抱着一种消极的态度，并且虽然没用检查过，但是时不时情绪大波动的我应该是有一点心理疾病。表现在耐心不足上，可对孩子最需要的就是耐心。所以我对家里催的态度说不。尽管他们说我没有孩子以后会多不好，但是我宁愿只是自己不好，毕竟孩子没法自己选择家庭不是吗？"

# %% [markdown]
# sentence = convert_emoji(sentence)

# %% [markdown]
# sentence = preprocess(sentence)

# %% [markdown]
# sentence

# %% [markdown]
# chunks = split2chunks(sentence)

# %% [markdown]
# print(chunks)

# %% [markdown]
# tokens = [tokenize(text) for text in chunks]

# %% [markdown]
# tokens

# %% [markdown]
# refine_n_revise(tokens)

# %%
def refine_n_revise(tokens):
    dep_token = []
    for token in tokens:
        #prepare the list for results
        new_token = []
        
        #initialize the substitution and removal lists
        sub_dict = {}
        remove_list = []
        
        #label dependencies with parser
        label_deps = parse_dependencies(token)
        
        #identify root
        try:
            root = next(dep['word'] for dep in label_deps if dep['relation']=='root')
        except TypeError:
            print('type error at comment', token)
            continue
            

        #identify subjects
        subject = [dep['word'] for dep in label_deps if dep['relation']=='nsubj']
        
        
        for dep in label_deps:
            #孩子相关
            child = {'孩子','小孩','宝宝','小孩儿','崽','崽崽','男孩','女孩','崽子','儿子','一个人','宠物','猫','狗'}
            verb = {'给','有','生','没','抱','带','养','爱','不要','要'}
            if dep['relation']=='obj' and dep['word'] in child and dep['governor'] in verb :
                dep['word'] = dep['governor']+dep['word']
                remove_list.append(dep['governor'])

            #connect root to its negation
            if dep['relation'] == 'advmod' and dep['word'] in {'不','没'} and len(dep['governor'])<=3:
                sub_dict.update([(dep['governor'], dep['word']+dep['governor'])])
                remove_list.append(dep['word'])
            
            #connect object to its negating adjective
            if dep['relation'] == 'obj' and dep['governor'] in {'没'} and len(dep['word'])<=3:
                sub_dict.update([(dep['word'], dep['governor']+dep['word'])])
                remove_list.append(dep['governor'])
                
            #connect verb to a different negation
            if dep['word']=='不了' and len(dep['governor'])<=2:
                sub_dict.update([(dep['governor'], dep['governor']+'不了')])
                remove_list.append('不了')
                
            #connect very to a different negation
            if dep['word']=='不好' and dep['governor'] in {'教','带','养','照顾','教育','做','当'}:
                sub_dict.update([(dep['governor'],dep['governor']+'不好')])
                remove_list.append('不好')

            #connect relatives to determiner
            relatives = {'爸爸','妈妈','父母','爸妈','父亲','母亲','亲妈','爹'}
            if dep['word'] in {'我'} and dep['governor'] in relatives:
                sub_dict.update([(dep['governor'], dep['word'] + '的' + dep['governor'])])

            #if root has aux, keep it (lets deal with it like this for now)
            if dep['governor']==root and dep['relation'] in {'aux','nmod','nmod:tmod','advcl'}:
                dep['relation']='xcomp'

            #if subject has compount, keep it
            if dep['governor'] in subject and dep['relation']=='compound':
                dep['relation']='xcomp'

        #take the designated types of dependencies and put them in results
        filterbylist = {'root','nsubj','nsubj:pass', 'obj','xcomp','csubj','amod'}
        filtered_deps = [dep for dep in label_deps if dep['relation'] in filterbylist]
        new_token.extend(list(set(dep['governor'] for dep in filtered_deps if dep['governor']!="ROOT")))
        new_token.extend([dep['word'] for dep in filtered_deps if dep['word']!=root and dep['word'] not in new_token])
        
        #if the root happens to get left out, put it in
        if root not in new_token:
            new_token.append(root)
        
        # substitute key terms and remove redundants
        if sub_dict!={}:
            new_token = [sub_dict.get(token, token) for token in new_token]

        if remove_list!=[]:
            new_token = [token for token in new_token if token not in remove_list]
        dep_token.append(new_token)
    
    return [item for sublist in dep_token for item in sublist]

# %%
the_doc = pd.read_csv("oid323836485_simplified.csv")
the_doc = the_doc[the_doc.vote==2]

# %%
comments = [comment for comment in the_doc.content]

# %%
comments_tokens = []
for comment in comments:
    sentence = preprocess(comment)
    sentence = convert_emoji(sentence)
    chunks = split2chunks(sentence)
    tokens = [tokenize(text) for text in chunks]
    new_tokens = refine_n_revise(tokens)
    comments_tokens.append(new_tokens)

# %%
len(comments_tokens)
# Out:
# 1943

# %%
replacement_rules = {}
add_replacements('replacement_rules2.txt', replacement_rules)
# Out:
# {'我的妈妈': '我妈',
#  '我的妈': '我妈',
#  '我的母亲': '我妈',
#  '我的亲妈': '我妈',
#  '老妈': '我妈',
#  '妈': '妈妈',
#  '爸爸妈妈': '爸妈',
#  '父母': '爸妈',
#  '爹妈': '爸妈',
#  '我的爸妈': '我的父母',
#  '我的父亲': '我爸',
#  '我的爸': '我爸',
#  '父亲': '爸爸',
#  '爸': '爸爸',
#  '爹': '爸爸',
#  'ta': '我的孩子',
#  '小孩': '小孩子',
#  '小孩儿': '小孩子',
#  '小朋友': '小孩子',
#  '崽': '小孩子',
#  '崽崽': '小孩子',
#  '娃': '孩子',
#  '宝宝': '小孩子',
#  '娃娃': '小孩子',
#  '生小孩': '生孩子',
#  '生娃': '生孩子',
#  '带娃': '带孩子',
#  '要孩子': '生孩子',
#  '有小孩': '有孩子',
#  '有娃': '有孩子',
#  '给小孩': '给孩子',
#  '男孩儿': '男孩',
#  '女孩儿': '女孩',
#  '小女孩': '女孩',
#  '小男孩': '男孩',
#  '我的小孩': '我的孩子',
#  '养蛙': '养孩子',
#  '男娃': '男孩',
#  '男孩子': '男孩',
#  '女娃': '女孩',
#  '女孩子': '女孩',
#  '娃儿': '小孩子',
#  '家里': '家庭',
#  '生': '生孩子',
#  '生子': '生孩子',
#  '结了婚': '结婚',
#  '小时候': '童年',
#  '女朋友': '女友',
#  '女生': '女人',
#  '男生': '男人',
#  '闺女': '女儿',
#  '不生孩子': '不生',
#  '男': '男人',
#  '女': '女人',
#  '害怕': '怕'}

# %%
megatoken = {}
add_replacements('megatoken.txt', megatoken)
# Out:
# {'车贷': '车与房',
#  '房贷': '车与房',
#  '没房': '车与房',
#  '没车': '车与房',
#  '房子': '车与房',
#  '租房': '车与房',
#  '车子': '车与房',
#  '买车': '车与房',
#  '有车有房': '车与房',
#  '车': '车与房',
#  '房': '车与房',
#  '买房子': '车与房',
#  '房车': '车与房',
#  '揭不开锅': '穷',
#  '再穷': '穷',
#  '穷苦': '穷',
#  '贫穷': '穷',
#  '没钱': '穷',
#  '世上': '世界',
#  '世间': '世界',
#  '人世间': '世界',
#  '人间': '世界',
#  '讨厌': '不喜欢',
#  '有钱': '钱',
#  '花钱': '钱',
#  '攒钱': '钱',
#  '赚钱': '钱',
#  '存钱': '钱',
#  '挣钱': '钱'}

# %%
def replace_rules(tokens,replacement_rules):
    for i in range(len(tokens)):
        if tokens[i] in replacement_rules:
            tokens[i] = replacement_rules[tokens[i]]   
        else:
            continue
    return tokens

# %%
comments_tokens1 = [replace_rules(comment, replacement_rules) for comment in comments_tokens]

# %%
comments_tokens1 = [replace_rules(comment, megatoken) for comment in comments_tokens1]

# %%
from collections import Counter
from itertools import chain
import csv

# %%
flat_tokens = list(chain.from_iterable(comments_tokens1))
token_counts = Counter(flat_tokens)
sorted_tokens = sorted(token_counts.items(), key=lambda x: (len(x[0]), -x[1]))

# %% [markdown]
# csv_file = 'token0201.txt'
#
# with open(csv_file, mode='w', encoding='utf-8', newline='') as file:
#     writer = csv.writer(file)
#     # Write the header
#     writer.writerow(['Token', 'Length', 'Frequency'])
#     # Write each token, its length, and frequency
#     for token, freq in sorted_tokens:
#         writer.writerow([token, len(token), freq])

# %%
stokens = [token_w_count[0] for token_w_count in sorted_tokens if token_w_count[1]>1]

# %%
labeled_tokens = [(token.word, token.flag) for token in pseg.cut(' '.join(stokens)) if token.word!=' ']

# %%
txt_file = 'single_char_tokens.txt' 
single_char_tokens = [token for token, freq in sorted_tokens if freq>1 and len(token) == 1] 
with open(txt_file, mode='w', encoding='utf-8') as file: 
    for token in single_char_tokens: file.write(token + '\n')

# %%
keep1c = {'why'}
with open("keep_1c_token.txt", 'r', encoding='utf-8') as f:
    for line in f:
        word = line.strip()
        keep1c.update(word)

# %%
final_tokens = []
coin = 0
for num in range(len(labeled_tokens)):
    if len(labeled_tokens[num][0])==1 and coin==0:
        if labeled_tokens[num][1] in {'a'} and sorted_tokens[num][1]<=120:
            final_tokens.append(labeled_tokens[num][0])
        elif labeled_tokens[num][0] in keep1c:
            final_tokens.append(labeled_tokens[num][0])
    
    if len(labeled_tokens[num][0])==2:
        coin+=1
        if labeled_tokens[num][1] in {'a','v','n','vn', 'an','nr'}:
            final_tokens.append(labeled_tokens[num][0])
    
final_tokens= final_tokens+['我妈','我爸','童年','不懂','不爱','不多','没钱']

# %%
threenfour = [token_w_count[0] for token_w_count in sorted_tokens if len(token_w_count[0]) in {3,4} and token_w_count[1]>3]
final_tokens = final_tokens+threenfour

# %%
final_tokens = [token for token in final_tokens if token not in {'觉得','感觉','感到','不了','干嘛','觉得','是因为','可能','达成','造成','有点','大','想要','不想要'}]

# %%
final_tokens = [token for token in final_tokens if token not in {'是否','算是','像是','是从','是不是','不就是','可不是'}]

# %%
len(final_tokens)
# Out:
# 1954

# %%
pd.DataFrame(final_tokens).to_csv('final_tokens0205.csv')

# %% [markdown]
# csv_file = 'parser_token_frequency.csv'
# with open(csv_file, mode='w', encoding='utf-8', newline='') as file:
#     writer = csv.writer(file)
#     # Write the header
#     writer.writerow(['Token', 'Length', 'Frequency'])
#     # Write each token, its length, and frequency
#     for token, freq in sorted_tokens:
#         writer.writerow([token, len(token), freq])

# %% [markdown]
# txt_file = 'single_char_tokens.txt'
# single_char_tokens = [token for token, freq in sorted_tokens if len(token) == 1]
# with open(txt_file, mode='w', encoding='utf-8') as file:
#     for token in single_char_tokens:
#         file.write(token + '\n')

# %%
filtered_comments = [
    [
        token for token in comment if token in final_tokens
    ]
    for comment in comments_tokens1
]

# %%
from gensim.models import Word2Vec

# %%
similar_words = Word2Vec(filtered_comments, vector_size=50, window=12, min_count=2, workers=4,sg=1,epochs=10)

# %%
similar_words.wv.most_similar('小孩子', topn=15)
# Out:
# [('可爱', 0.9343622922897339),
#  ('不喜欢', 0.9229201674461365),
#  ('喜欢', 0.9047781229019165),
#  ('处理', 0.8838791847229004),
#  ('哭', 0.8522584438323975),
#  ('情绪', 0.8372146487236023),
#  ('幼崽', 0.8321914076805115),
#  ('照顾不好', 0.8274630308151245),
#  ('怕', 0.8250404000282288),
#  ('脾气', 0.8204468488693237),
#  ('厌恶', 0.8194323778152466),
#  ('不稳定', 0.8174711465835571),
#  ('外甥', 0.8164674639701843),
#  ('惹事', 0.8122392892837524),
#  ('狗狗', 0.8067873120307922)]

# %%
similar_words.wv.similarity('婚','结婚')
# Out:
# 0.8430261

# %%
from gensim import corpora, models

# %%
final_tokens1 = [token for token in final_tokens if token not in {'孩子','小孩子','生孩子','没有','不想','不生','问题','时候'}]
filtered_comments1 = [
    [
        token for token in comment if token in final_tokens1
    ]
    for comment in comments_tokens1
]

# %%
dictionary = corpora.Dictionary(filtered_comments1)
dictionary.filter_extremes(no_below=2, no_above=0.8, keep_n=500)
corpus = [dictionary.doc2bow(comment) for comment in filtered_comments1]

tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
lda_model = models.LdaModel(corpus_tfidf, num_topics=20, id2word=dictionary, passes=30)

# %%
for idx, topic in lda_model.print_topics():
    print(f"Topic: {idx+1} \nWords: {topic}\n")
# Out:
# Topic: 1
# Words: 0.036*"多" + 0.034*"领养" + 0.033*"原因" + 0.023*"玩" + 0.020*"共情" + 0.018*"家庭" + 0.018*"条件" + 0.017*"受罪" + 0.016*"希望" + 0.016*"意义"
#
# Topic: 2
# Words: 0.055*"世界" + 0.053*"自私" + 0.048*"妈妈" + 0.034*"劝" + 0.032*"受苦" + 0.031*"来到" + 0.027*"不活" + 0.027*"体验" + 0.023*"明白" + 0.021*"自由"
#
# Topic: 3
# Words: 0.048*"我妈" + 0.027*"信心" + 0.023*"经历" + 0.021*"决定" + 0.021*"负担" + 0.019*"情绪" + 0.018*"状态" + 0.018*"准备" + 0.016*"做好" + 0.015*"不稳定"
#
# Topic: 4
# Words: 0.042*"责任" + 0.035*"承担" + 0.034*"照顾" + 0.031*"无所谓" + 0.030*"婚" + 0.022*"生不生" + 0.021*"愿意" + 0.021*"人家" + 0.021*"能力" + 0.019*"选择"
#
# Topic: 5
# Words: 0.034*"想想" + 0.025*"操心" + 0.024*"提供" + 0.021*"事情" + 0.020*"无法" + 0.019*"拒绝" + 0.018*"低" + 0.018*"崩溃" + 0.018*"满足" + 0.017*"病"
#
# Topic: 6
# Words: 0.077*"苦难" + 0.073*"养孩子" + 0.058*"喜欢" + 0.056*"怕" + 0.053*"催" + 0.052*"猫" + 0.047*"结婚" + 0.034*"养不好" + 0.026*"穷" + 0.021*"应该"
#
# Topic: 7
# Words: 0.088*"穷" + 0.028*"家庭" + 0.023*"思想" + 0.019*"改变" + 0.017*"影响" + 0.017*"接受" + 0.016*"祸害" + 0.015*"年龄" + 0.015*"不知道" + 0.015*"伤害"
#
# Topic: 8
# Words: 0.048*"苦" + 0.041*"孤独" + 0.041*"后悔" + 0.038*"视频" + 0.030*"不能" + 0.028*"女性" + 0.026*"快乐" + 0.026*"选择" + 0.025*"生育" + 0.025*"还有"
#
# Topic: 9
# Words: 0.052*"爱" + 0.044*"一个人" + 0.044*"有孩子" + 0.042*"男孩" + 0.031*"女孩" + 0.025*"需要" + 0.023*"时间" + 0.020*"不能" + 0.019*"不理解" + 0.019*"选择"
#
# Topic: 10
# Words: 0.065*"尊重" + 0.045*"祝福" + 0.045*"老" + 0.043*"死" + 0.038*"道理" + 0.034*"权利" + 0.030*"清楚" + 0.028*"不考虑" + 0.027*"实力" + 0.026*"丁克"
#
# Topic: 11
# Words: 0.047*"钱" + 0.032*"情况" + 0.027*"支持" + 0.024*"不幸福" + 0.024*"简单" + 0.023*"足够" + 0.022*"我会" + 0.022*"继续" + 0.022*"选择" + 0.021*"骂"
#
# Topic: 12
# Words: 0.045*"身体" + 0.039*"绑架" + 0.036*"普通人" + 0.033*"不用" + 0.032*"累" + 0.031*"遗传病" + 0.029*"独立" + 0.027*"要不要" + 0.026*"道德" + 0.026*"值得"
#
# Topic: 13
# Words: 0.051*"不知道" + 0.047*"不婚不育" + 0.041*"不会" + 0.034*"有没有" + 0.034*"母亲" + 0.034*"我的父母" + 0.033*"可爱" + 0.024*"不婚" + 0.023*"不喜欢" + 0.023*"看见"
#
# Topic: 14
# Words: 0.226*"不喜欢" + 0.055*"逼" + 0.039*"选择" + 0.036*"狗" + 0.029*"带来" + 0.025*"考虑" + 0.024*"负责" + 0.023*"伤害" + 0.023*"意愿" + 0.022*"不幸"
#
# Topic: 15
# Words: 0.082*"女人" + 0.073*"男人" + 0.046*"生命" + 0.030*"压力" + 0.028*"遇到" + 0.025*"麻烦" + 0.022*"对方" + 0.018*"社会" + 0.016*"遗传" + 0.015*"爱"
#
# Topic: 16
# Words: 0.031*"幸福" + 0.025*"爸妈" + 0.021*"不结婚" + 0.018*"带来" + 0.017*"成为" + 0.014*"不觉得" + 0.013*"钱" + 0.013*"成长" + 0.012*"不会" + 0.012*"不确定"
#
# Topic: 17
# Words: 0.041*"最好" + 0.041*"给不了" + 0.034*"生活" + 0.033*"教育" + 0.029*"活着" + 0.029*"投票" + 0.027*"女儿" + 0.024*"想生" + 0.021*"打死" + 0.020*"生活质量"
#
# Topic: 18
# Words: 0.065*"人生" + 0.042*"车与房" + 0.029*"养不起" + 0.025*"条件" + 0.023*"家长" + 0.022*"差" + 0.020*"环境" + 0.019*"折磨" + 0.019*"累" + 0.017*"买"
#
# Topic: 19
# Words: 0.061*"痛苦" + 0.043*"负责" + 0.038*"基因" + 0.030*"对象" + 0.029*"儿孙" + 0.027*"想到" + 0.026*"概率" + 0.025*"担心" + 0.022*"高" + 0.022*"恐惧"
#
# Topic: 20
# Words: 0.135*"生不了" + 0.075*"大家" + 0.067*"丁克" + 0.042*"伟大" + 0.038*"怎么办" + 0.035*"下一代" + 0.035*"爸爸" + 0.032*"男性" + 0.031*"钱" + 0.030*"传宗接代"

# %%
doc_topic_dist = []
for doc in corpus:
    doc_topics = lda_model.get_document_topics(doc, minimum_probability=0.0)
    doc_topic_dist.append([topic[1] for topic in doc_topics])

# %%
doc_topic_df = pd.DataFrame(doc_topic_dist, columns=[f"Topic {i+1}" for i in range(lda_model.num_topics)])
doc_topic_df["Document"] = [comment for comment in comments]

# %%
top_docs_per_topic = {}
for topic_num in range(lda_model.num_topics):
    sorted_docs = doc_topic_df.sort_values(by=f"Topic {topic_num+1}", ascending=False)
    top_docs_per_topic[f"Topic {topic_num+1}"] = sorted_docs.head(7)  # Top 3 documents for this topic

# %%
for topic, top_docs in top_docs_per_topic.items():
    print(f"\n{topic}:")
    print(top_docs[["Document", f"{topic}"]])
# Out:
# Topic 1:
#                                                Document   Topic 1
# 650   我不想因为自己没金钱没时间没能力还要生孩子然后让ta受苦让ta自卑，比起ta懂事听话地说不用...  0.932137
# 64          暂时不要，等我有能力赚到钱了，或者人口少到一定地步，买房子生孩子成本降低的时候再考虑生  0.881245
# 195   人活一辈子无非受苦受难真正开心的日子感觉不超过100天所以除非家里真的有矿要不就别生了苦孩子...  0.864284
# 1131  深有感触，所以作为老大的我，真的无法对我爸妈有太大的共情，当初决定生四胎的是他们，很大一定程...  0.864279
# 1309  生孩子的意义是什么呢？各有说法没有正答，我觉得能找到自己生孩子的意义很重要，但现实里可能是被...  0.864277
# 1713                 我选择不生的原因是因为现在社会已经够卷够苦了，何必生孩子让孩子受罪呢  0.841665
# 364       能力不行的人生孩子既毁了自己也毁了孩子。因为原生家庭的原因，我对结婚生儿育女没有任何期待。  0.841665
#
# Topic 2:
#                                                Document   Topic 2
# 447                  呃我活的太幸福了，我只能享受被爱，我不想付出我就是自私，自私活的开心  0.894440
# 827   其实自私在这方面也有不同的表现。。有人选择生孩子拖孩子下水，还有我这种怪人，做不到无私地利他...  0.881245
# 759        如果有机会做选择我不愿意来到这个世界上，既然我不想要为什么要让另一个人也体验一下[微笑]  0.864283
# 44    我只是小姨，陪外甥睡觉，小孩子晚上睡觉很不老实，经常踢被子，而且有时会睡着睡着哭起来，作为一...  0.864278
# 492                    孩子只会重复我经受的苦难，不让他来到这个世界是我对他最大的善意。  0.841665
# 1486                  我对我的孩子最大的爱就是别让他or她来到这个世界上受苦受难[笑哭]  0.809999
# 867   借用一句真探里的话，我认为我们这个物种最崇高的事就是“brothers and sister...  0.786739
#
# Topic 3:
#                                                Document   Topic 3
# 883   我希望等我想要孩子的时候我能有稳定的经济基础，可以给她/他充足的爱，可以给她/他一个情绪足够...  0.936665
# 800   弹幕有人质问：“那你是怎么来的?”。对，我是父母生下来的，但是我不是自愿的，如果给我一个机会...  0.913629
# 1639  我说不生我妈总说我没社会责任感，但事实是以我目前的状态选择不生才是有社会责任感的表现。结婚生...  0.894442
# 1739          我情绪总是不稳定，也不是很喜欢小孩子，我相信也不会有人希望自己有个情绪不稳定的母亲  0.894442
# 1642  不生，我自己曾是留守儿童，从小学开始寄宿，经历过搬家、换学校等不稳定的生活，曾一度想要离开世...  0.894441
# 1612      因为没办法也没有一点信心能教育好孩子，非常害怕以后孩子会变成翻版的自己，所以我不会要孩子。  0.881246
# 1165  我都已经做好不要孩子的准备了，也一直努力避孕，婚后四年多都没有怀过，就那一次我俩出去旅行忘了...  0.864283
#
# Topic 4:
#                                                Document   Topic 4
# 345   生与不生是个人选择，然而你们会发现每次在讨论生不生这个问题的时候，首先展露攻击的 倒不是“选...  0.894442
# 9     我喜欢小孩，也会想生，但一定是自己有能力的情况下，并且只想给爱的人，爱我的人生，那种大男子主...  0.881247
# 631   点错了，孩子还是非常可爱的，看着他慢慢长大非常有成就感，虽然肯定会带来很多责任，不少困难。但...  0.881243
# 1556  说得好，而且部分女性把生育当筹码要求男性无限制退让很离谱。\n生了孩子之后，养育和付出该是合...  0.864282
# 300   家里有个弟弟，长姐如母真的不是开玩笑的，照顾弟弟这么多年感觉自己还是个孩子却养了一辈子孩子了...  0.841664
# 636   不想生孩子。生孩子真的对女性身体伤害有不可逆的损伤，我觉得凉薄如我目前为止还没有谁能让我感情...  0.841651
# 1058                                  承担不起责任是父母给孩子一生的诅咒  0.809999
#
# Topic 5:
#                                                Document   Topic 5
# 1487  我从初中就一直排斥生育，因为我是个特别怕疼的人，知道怀孕要剖腹产或者撕裂下体然后生出来，我光...  0.913629
# 1280  我妈这样跟我说的，“你俩要不要小孩，跟我没啥关系，因为我到最后是你俩给我送走，你俩是谁送走，...  0.894442
# 211   有一句话到现在仍在到处流传“富养有富养的活法，穷养有穷养的活法”我真的只想说，不要给自己的不...  0.864280
# 395        想一个孩子需要非常多的钱，而且还有很多事情需要操心，对于我来说太重了，我没责任，也不想担  0.841664
# 935   虽然我现在怀孕，但是我想说我在1个月每天睡不着觉的时候就后悔了，并且不想之后我的孩子生孩子，...  0.809998
# 493            我觉得现在很多有孩子的人为了孩子而工作，还push别人，真的让人无法理解[捂脸]  0.809997
# 181                           领养代替生育，毕竟养别人的孩子比自己生孩子风险要小  0.809995
#
# Topic 6:
#                                                Document   Topic 6
# 1268  生育自由 结婚自由 性取向自由 我们有自己的朋友 我们没那么孤独 怕养不起养不好孩子是我们有...  0.920828
# 1609  当我发现我毫无保留的继承了原生家庭的缺点，变成了记忆中父母的样子的时候，我开始仔细思考要不要生孩子  0.881243
# 854   为什么只有网上才能看到不想要孩子的男生[藏狐]现实生活中基本上没有~~身边的女生朋友当初说不...  0.864282
# 1367  能生而选择不生的人中应该有很大一部分是因为太爱孩子，想不生但还是生的应该是抵抗不了世俗，都能理解。  0.841654
# 1727            不想生孩子，不想结婚，很害怕。但是也很害怕最后会屈服于父母的“任务”[辣眼睛]  0.809999
# 1871    我大概现在连我自己都活得不是很明白，还是算了吧[妙啊][妙啊][妙啊]养个猫都感觉好麻烦哈哈哈  0.809997
# 1110  你不应该单独举例开头哪位40多岁大叔，应该举例成功人士再加上比例就会发现真的没有多少[tv_...  0.809992
#
# Topic 7:
#                                                Document   Topic 7
# 1564  我老家北方的，我们那巷家有个女儿，一到冬天全身皮肤像龟壳一样开裂，腿部皮肤还会渗出血丝，看着...  0.913631
# 1336  我有两个娃娃，但感觉一直在自我否定的路上，孩子生病心疼，觉得自己无能，读书其他等等事情都觉得...  0.881246
# 1528  哥们没钱，不习惯和别人作伴过日子所以不结婚，自己精神状态不是时时刻刻稳定感情薄弱所以不适合要...  0.881242
# 1080  不要孩子，是因为心理年龄没到，各方条件不足，没有对象，没有钱，没有一个有爱的家庭氛围，总的来...  0.864283
# 1044   好多人喜欢问你为啥不生，我就很纳闷这个问题是怎么提出来的，做出改变需要理由，保持现状才不需要原因  0.864281
# 1483             我见过很多贫困地区的家庭，明明家里穷的揭不开锅，还得生好几个孩子，为了什么？  0.809999
# 1303     我觉得不止是穷家庭，有的家庭有一定的经济条件，却又想生孩子又不愿意在孩子身上花钱的也不应该生  0.809999
#
# Topic 8:
#                                                Document   Topic 8
# 713    我觉得既然不能给予下一代足够好的物质条件和教育，真的不能生。对孩子好也对我好，我不想死而且我怕疼  0.864284
# 1400                  生育是人作为动物的基本要求，不是社会因素谁不想生孩子当爸爸妈妈呢。  0.864279
# 1026  生育是对女性的压迫，所以在人造子宫工厂全面普及前，我绝不生育[doge]（不是因为我喜欢快乐...  0.841665
# 1328  除了成长条件教育条件环境条件物质条件等，我怕生出来第二个我，满脑袋煞气每天抱怨着生活在这个世...  0.809997
# 1543  我从13岁开始当铲屎官，到现在已经当了十年铲屎官了，养育一只宠物都要费心费力，何况一个孩子，...  0.809994
# 880                         孤独是人必须有的东西，人不能没有他人，更不能没有自己。  0.762499
# 1243                我就是怕疼受不了苦，不愿为孩子累死累活，操碎了心。我生不生，关你屁事。  0.762498
#
# Topic 9:
#                                                Document   Topic 9
# 984   为什么会盼着孩子给自己养老呢？不防看看现在我们自己，有多少时间能陪伴父母的？而且有了孩子之后...  0.920828
# 1779  孩子三岁 我很爱我的孩子 和爱人一起带孩子 我们两人都是负责有爱的人 我们的孩子也很爱我们 ...  0.864284
# 1924  昨天跟爸妈闲聊的时候刚聊到这个话题，我们一致觉得不要孩子对我们都好，爸妈没时间帮忙带，我也没...  0.841663
# 512   单单就时间问题国家都做不到，更别说福利什么的。\n比如有孩子的父母所有工作时间强制跟随孩子上...  0.841659
# 902                             因为我感觉我更爱自己，没有太多时间放在孩子身上  0.809997
# 1124  我小时候想要两个孩子，因为我家就是两个，我觉得都能顾得上她们还能相互护持。后来大了，我觉得我...  0.809995
# 890                生就生吧，但是有些家长也应该好好去教育小孩，不是只生不养，给别人造成困扰  0.809993
#
# Topic 10:
#                                                Document  Topic 10
# 1649           以我目前的认知，我认为家里没有背景没有权利没有实力，生下来的小孩以后也是打工的命  0.809997
# 1155          养只狗我都觉得麻烦，而且当了二十多年孩子，能不啃老都很厉害了，我也没啥能力让孩子啃  0.809992
# 1598  不管生不生都尊重\n人要清楚关你屁事，和关我屌事\n不管对方是穷人还是富人，生和不生产生的后...  0.809991
# 731                           丁克到 37 的来了，你们生，我尊重祝福。[OK]  0.762499
# 681   丁克祝福生孩子的，生孩子的对丁克恶语相向这就好像什么。路上有人掉坑里了你上去安慰人，人看你知...  0.762498
# 93                           我有让孩子不来这个世界上受二茬罪的权利，这是我的权利  0.762498
# 1422                        坚定丁克，找男朋友都费劲，但是不能丁克到底的真的不敢谈  0.735497
#
# Topic 11:
#                                                Document  Topic 11
# 448                     我是怕痛，如果不是生病我不会允许自己身上被开一个口子，想想都痛  0.864280
# 734                      有足够的钱我也不想生，生孩子带来的身体代价谁生谁知道[支持]  0.841665
# 1902  而且有的时候不是威逼利诱，我们这代继续盛行丁克到时候肯定也会面临老龄化问题，所谓老有所养老有...  0.819782
# 1551  不生是因为我觉得自己生气起来和妈妈太像了，有时候下意识对狗狗说的话都会让我头皮发麻，我也没有...  0.809997
# 665                      孩子究竟有没有用，我看看自己什么逼样就知道了[小电视_发愁]  0.809996
# 646            我连恋爱的欲望都没有，而且很早以前就恐婚了。生小孩代价太大，我也不想要什么回报。  0.809989
# 1518  坚决不要，如果实在找不到好人的话婚也不想结[doge]三胎政策不是给什么补贴吗我只能说在我这...  0.804238
#
# Topic 12:
#                                                Document  Topic 12
# 1715              我不要孩子是为了孩子好 我一定会是个控制欲很强 不把孩子当成独立个体的家长  0.841660
# 1282                     这世界上没有任何一个人有资格让我付出一辈子的身体损伤要个孩子  0.809994
# 1914                            养狗都很累了，很多人还没我养狗的耐心去养小孩。  0.762499
# 1899  按照我爸养我的经历来看，我的孩子跟我一样＝我要付出巨大金钱精力，我的孩子不如我＝我要付出超级...  0.742619
# 1910  我十几岁的时候过我们家这边的一座桥，桥上的人行道有一个姐姐，肚子里有一个，右手抱着一个，左手...  0.685351
# 153      [笑哭]和小朋友互动一个小时就觉得累了,更不要说他们精力很充沛,真的容易没电,再说还要打工呢  0.683332
# 1033  我有精神问题，看到别家孩子哭闹我有想把他揍一顿让他闭嘴的冲动，看他在地上爬来爬去，随便抓个东...  0.683331
#
# Topic 13:
#                                                Document  Topic 13
# 1735  为什么我要生呢？我的家庭环境，我的父母都是不太好，知识层面不太高我难道要让我的孩子生下来承受...  0.881246
# 626                     小时候没有幻想过结婚，长大发现各种现实问题之后更不打算结婚了，  0.864284
# 1266             再说了。就算我是报复性不生，单纯的讨厌，看见孩子就想着怎么处理掉，那又怎么样  0.809999
# 1865  自己都教育不好，怎么教育孩子？一个孩子需要充足物质，和完整的人格。  而有的，真正的房间物质...  0.793178
# 1589  父母没教会我爱，我不知道怎么爱人，也不知道自己能不能学会爱孩子，我不想伤害ta，不想把我的痛...  0.774982
# 1473       儿女双全，但我真不建议要孩子。你们大学生根本不知道医疗有多贵！根本不知道生孩子多伤身体！  0.762498
# 697                                我不会是好父母，就不生了，喜欢孩子的加油  0.762498
#
# Topic 14:
#                                                Document  Topic 14
# 1376              一不喜欢小孩\n二受不了生孩子给身体带来的伤害\n三没钱\n\n综上：不生  0.864284
# 1710             不要，\n一我没钱，二我讨厌照顾孩子，三害怕孩子患上基因病或者其他疑难杂症，  0.841663
# 743   不要，没法负责。我很怕多少会带上原生家庭的一些坏习惯，这对我和孩子都是伤害，没必要。而且我也...  0.841663
# 177   不生不是我讨厌小孩，第一是我就不喜欢生育这件事，在道德上我不允许我这么做 第二是因为这对妇女...  0.841663
# 863   哇 up真的点醒我了 虽然一直都晓得劝生的人在想啥 但还是第一次有人总结出来：不想生孩子的人...  0.841662
# 101       讨厌小孩，讨厌大吵大闹听不懂人话的东西，甚至讨厌人类，讨厌平凡庸俗的自己！毁灭吧！全部都！  0.841662
# 488   不喜欢孩子，孩子生出来了要对他负责，都不知道为谁生这孩子，干嘛让他出世，某种意义上来说，对他...  0.809998
#
# Topic 15:
#                                                Document  Topic 15
# 264   为什么选择不生，因为我的爷爷就有遗传类疾病，现在一直延续到了我这里，知道每时每刻都被病魔缠身...  0.881245
# 284   可能是不想让ta想我一样，刚出学校一两年就被催婚[喜极而泣][喜极而泣][喜极而泣][喜极而...  0.881241
# 1313  目前已育一女，10个月。自己带，麻的快累死我了，劳累程度跟生之前预期的更本不一样。当时觉得自...  0.864283
# 1896  我觉得是现实环境导致的吧，除了家里人。个人和对象都不想要孩子。生小孩的疼痛也不想给她。后续的...  0.841660
# 1200  老人拿菜刀抵在脖子上逼我和我老公答应一年内要娃的经历 我估计网上不太多吧[翻白眼][翻白眼]...  0.841656
# 975        弱弱的问一句：现在男多女少，难道不是因为女人嘎掉的时候都在想【下辈子绝对不要当女人】么…  0.809998
# 1654  但凡看完生育的各种疾病风险、进一步再看几部论文或纪录片，还能坚定生孩子的女性，我是真的佩服，...  0.809995
#
# Topic 16:
#                                                Document  Topic 16
# 348   等有钱了，再考虑是否领养一个，因为太痛苦了我活着，希望有能力帮一个孩子，顺便把我的思想传递给...  0.920831
# 725   不生是因为我也做过别人的孩子，我知道一个小孩子最想要的是什么。我不确定我可以成为让我的孩子回...  0.913634
# 1936  我知道自己生的孩子会给自己带来很多很多内源动力，看着小朋友慢慢长大成为大朋友是很幸福的一件事...  0.904998
# 739            因为我不会给他带来快乐 我没法让他拥有一个幸福的生活 他应该去能让他更幸福的家里  0.894443
# 678   选择不要孩子，原因很简单:要不起。 成长于一个风雨飘摇的家庭，活成了不开心的父母，自己前途暗...  0.894442
# 1729  人作为一个生物没有不想生孩子的，这是我们的本能，也可以理解为繁衍是永生的一种体现，所以生了孩...  0.894440
# 1537  领养小朋友或者说养不是自己生的小朋友总给我一种顾虑，这部分只是排除了生育的风险部分，但是养和...  0.881243
#
# Topic 17:
#                                                Document  Topic 17
# 627   不生，我要自由，不想因为ta来束缚我。同时也怕ta怨恨我，我给不了ta什么，我是吗喽，生个小...  0.881246
# 695                        我不能保证可以让孩子有好的生活，也不能保证她的父亲是好的  0.864284
# 94              我知道自己的斤两，也知道，给不了孩子衣食无忧的生活，我能养活自己就已经很不错了  0.864284
# 694                              没有那个经济能力，并且也没有教育好孩子的能力  0.809998
# 1377  生孩子会耽误我很多事，会耽误我的事业和吃喝玩乐以及各种各样的计划，我不想过为了孩子妥协这妥协...  0.809998
# 676   唉，我认识一个弟弟，上面九个姐姐，不生出男孩不罢休，他爹都70了。。。结果他是个通讯录[笑哭]。。  0.809996
# 1653     给不了好的生活，就不要。而且现在人也找不到对的。两次选择已经选错了一次。剩下的一次，不敢选了  0.809993
#
# Topic 18:
#                                                Document  Topic 18
# 1787  我工作后考了五年才考上编制，首先我是打算考不上就不生孩子的，不然生育带来的身体创伤加上失业后...  0.893616
# 525   我记得十几年前还有健康杂志说，不生孩子的女人雌激素水平过高，容易得乳腺癌，生过一次孩子可以降...  0.841658
# 251             没钱没时间没房没车没存款父母没工作没存款没养老金，生了真的对我对孩子是好事吗？  0.809999
# 182                             不生孩子只是为了不让另一个生命经历我悲惨的人生  0.809997
# 1416  我看的很开，人生十几年，生孩子不如把自己当孩子养。把养育孩子的钱花在“养育”自己身上，学以前...  0.809997
# 1491   我不觉得我会是什么负责任的人，况且我自己的心理问题也不轻，我可不想让孩子面对我这种烂家长[难过]  0.809997
# 1301  没钱，自己花都快不够用了，也不要自己的身体有那么一点点概率遭受折磨（何况这不是概率事件是必然...  0.809996
#
# Topic 19:
#                                                Document  Topic 19
# 1372  我可太了解我自己了，我连对自己负责都做不到，何谈对爱人对孩子负责？我本性就是个自私自利的人，...  0.894442
# 522   我突然想到了那个叫“半佛”的up，他嘴上劝着要对孩子负责不要把孩子当工具人，要优生优育，自己...  0.841665
# 750                         想养个狗但是觉得自己精力不够，对象和孩子更是不敢想了。  0.841662
# 1355              儿孙自有儿孙福，没有儿孙我享福，养出一个能防老的孩子的成本要远远高于靠自己  0.809999
# 613   其实和爱的人有一个可爱的宝宝是个很幸福的事情 但是怕自己现实中找不到靠谱爱家爱孩子负责任的好...  0.796384
# 1323                                    儿孙自有儿孙福，没有儿孙我享福  0.762499
# 1121                              还是那句话,儿孙自有儿孙福，没有儿孙我享福  0.762499
#
# Topic 20:
#                                                Document  Topic 20
# 888   [难过][难过]如果大家都不要孩子的话，养老设施、场所必然会因为需要而改进吧[保卫萝卜_哭哭...  0.841660
# 496   有钱＝少很多烦恼，包括要不要孩子，当然，我没钱，所以我不要，万一某天我有钱，我还是会“要孩子...  0.826711
# 1304  [保卫萝卜_哭哭]这个问题真的是我一个月薪三千的人能想的起的问题吗？就赚这三千都已经让我精疲...  0.809998
# 489                             生孩子让他继承我的穷苦命吗 还是别祸害下一代了  0.762497
# 1907         “不生孩子，你老了怎么办，病死在家都没人知道！”\n“我知道，我自己选的，我活该。”  0.762494
# 1701  作为一个男性 生孩子的事儿也不是我能左右的\n另一半的意见才是最重要的\n当然了 前提是我有...  0.722359
# 573   我记得欧洲只有贵族以上阶级才有传宗接代的观点，平民没有。这是对的，人家贵族传宗接代是因为有爵...  0.693036

# %%
comments[1654]
# Out:
# '但凡看完生育的各种疾病风险、进一步再看几部论文或纪录片，还能坚定生孩子的女性，我是真的佩服，我是绝对不干这亏到姥姥家的事了，我不劝别人 别人也别劝我好吧。'

# %%
def kmeans_clustering(model, num_clusters):
    words = list(model.wv.index_to_key)
    word_vectors = model.wv.vectors
    
    kmeans = KMeans(n_clusters=num_clusters, init='k-means++', random_state=42)
    kmeans.fit(word_vectors)
    
    clusters = {}
    for i, word in enumerate(words):
        cluster = kmeans.labels_[i]
        if cluster not in clusters:
            clusters[cluster] = [word]
        else:
            clusters[cluster].append(word)
    
    return clusters

# %%
clusters = kmeans_clustering(similar_words, 10)
# Out:
# /Users/xiangningxu/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.cluster import KMeans

# %%
clusters
# Out:
# {2: ['孩子',
#   '没有',
#   '生活',
#   '不能',
#   '能力',
#   '条件',
#   '我的孩子',
#   '教育',
#   '考虑',
#   '时间',
#   '环境',
#   '我的父母',
#   '童年',
#   '保证',
#   '足够',
#   '给孩子',
#   '受苦',
#   '给不了',
#   '家长',
#   '办法',
#   '快乐',
#   '最好',
#   '健康',
#   '没办法',
#   '成长',
#   '下一代',
#   '提供',
#   '陪伴',
#   '耐心',
#   '拥有',
#   '信心',
#   '物质条件',
#   '指望',
#   '培养',
#   '满足',
#   '物质',
#   '能够',
#   '做到',
#   '担心',
#   '需求',
#   '机会',
#   '生活质量',
#   '给予',
#   '资源',
#   '充足',
#   '富足',
#   '富裕',
#   '金钱',
#   '心态',
#   '良好',
#   '健全',
#   '挣扎'],
#  9: ['生孩子',
#   '不生',
#   '不会',
#   '知道',
#   '身体',
#   '自私',
#   '希望',
#   '需要',
#   '一个人',
#   '经历',
#   '苦难',
#   '社会',
#   '明白',
#   '死',
#   '肯定',
#   '决定',
#   '一辈子',
#   '付出',
#   '孤独',
#   '领养',
#   '最大',
#   '作为',
#   '不让',
#   '带孩子',
#   '简单',
#   '基因',
#   '风险',
#   '重要',
#   '性格',
#   '影响',
#   '想想',
#   '看看',
#   '支持',
#   '美好',
#   '理由',
#   '告诉',
#   '改变',
#   '感受',
#   '期待',
#   '不稳定',
#   '遗传',
#   '普通人',
#   '精神',
#   '得到',
#   '延续',
#   '不确定',
#   '婚姻',
#   '优秀',
#   '更何况',
#   '疾病',
#   '不幸福',
#   '怕疼',
#   '伟大',
#   '清楚',
#   '变得',
#   '无所谓',
#   '意义',
#   '没能力',
#   '状态',
#   '行为',
#   '善良',
#   '照顾不好',
#   '抚养',
#   '心理',
#   '脾气',
#   '不适合',
#   '实现',
#   '老一辈',
#   '才能',
#   '厌恶',
#   '恋爱',
#   '确定',
#   '跟着',
#   '属于',
#   '权利',
#   '水平',
#   '损伤',
#   '不幸',
#   '爱孩子',
#   '一般',
#   '祸害',
#   '前提',
#   '动物',
#   '学习',
#   '拒绝',
#   '不负责',
#   '长辈',
#   '思考',
#   '这辈子',
#   '人类',
#   '过程',
#   '生不生',
#   '没必要',
#   '不够',
#   '养不好',
#   '创造',
#   '困难',
#   '什么样',
#   '允许',
#   '做出',
#   '控制',
#   '放弃',
#   '不开心',
#   '实力',
#   '伴侣',
#   '学会',
#   '受到',
#   '不活',
#   '因素',
#   '要求',
#   '另一半',
#   '适合',
#   '束缚',
#   '好孩子',
#   '产生',
#   '内心',
#   '不打算',
#   '双方',
#   '降低',
#   '不允许',
#   '不可逆',
#   '老路',
#   '生存',
#   '不多',
#   '自卑',
#   '个体',
#   '传递',
#   '养好',
#   '人格',
#   '不太好',
#   '下降',
#   '打算',
#   '失去',
#   '对不起',
#   '值得',
#   '欲望',
#   '受不了',
#   '后果',
#   '对待',
#   '不快乐',
#   '遗憾',
#   '价值',
#   '强',
#   '处于',
#   '帮助',
#   '单纯',
#   '体会',
#   '生就',
#   '倾向',
#   '投入',
#   '保障',
#   '在我看来',
#   '就行了',
#   '近视',
#   '成熟',
#   '存在',
#   '经济基础',
#   '损害',
#   '别提',
#   '生养',
#   '达到',
#   '工具',
#   '带到',
#   '干什么',
#   '教导',
#   '情感',
#   '没活',
#   '无辜',
#   '留下',
#   '现实',
#   '做不了',
#   '不配',
#   '极端',
#   '暴躁',
#   '状况',
#   '生来',
#   '内卷',
#   '情绪稳定',
#   '催婚',
#   '毁',
#   '衣食无忧',
#   '幼崽',
#   '爱好',
#   '爱人',
#   '深知',
#   '意识',
#   '支撑',
#   '范围',
#   '残酷',
#   '成绩',
#   '艰难',
#   '治愈',
#   '追求',
#   '本能',
#   '身体健康',
#   '生气',
#   '很多很多',
#   '各种各样',
#   '猫猫',
#   '新',
#   '皇位',
#   '不成熟',
#   '制造',
#   '避免',
#   '责任感',
#   '等到',
#   '抗拒',
#   '认识',
#   '承认',
#   '半辈子',
#   '未知',
#   '不足',
#   '养宠物',
#   '负面',
#   '不值得',
#   '心血',
#   '优渥',
#   '关注',
#   '无关',
#   '解决',
#   '压抑',
#   '资本',
#   '其他人',
#   '基本',
#   '确保',
#   '顺其自然',
#   '不听话',
#   '出息',
#   '竞争',
#   '有钱人',
#   '梦想',
#   '教养',
#   '没法',
#   '有限',
#   '母爱',
#   '危害',
#   '没准备',
#   '健康成长',
#   '处理',
#   '胆小',
#   '一点点',
#   '目标',
#   '诞生',
#   '灵魂',
#   '算了',
#   '不带来',
#   '恨不得',
#   '养出',
#   '经受',
#   '走一遍',
#   '度过',
#   '指责',
#   '重蹈覆辙',
#   '灾难',
#   '产物',
#   '爆炸',
#   '毛病',
#   '不生育',
#   '建立',
#   '证明',
#   '无法忍受',
#   '担不起',
#   '结晶',
#   '担当',
#   '健健康康',
#   '勉强',
#   '不放心',
#   '长大成人',
#   '强大',
#   '任何人',
#   '限制',
#   '坚强',
#   '亲密关系',
#   '缺点',
#   '起跑线',
#   '消耗',
#   '不公平',
#   '利益',
#   '连累',
#   '鼓励',
#   '弊大于利',
#   '不来到',
#   '完美',
#   '干涉',
#   '幸福感',
#   '聪明',
#   '交给',
#   '太苦',
#   '糟糕',
#   '见识',
#   '对错',
#   '尽全力',
#   '改善',
#   '把握',
#   '事物',
#   '修复',
#   '十几年',
#   '呵护',
#   '角度',
#   '消失',
#   '与否',
#   '传承',
#   '身材',
#   '玩耍',
#   '宁可',
#   '迎接',
#   '财力',
#   '适用',
#   '确认',
#   '热爱',
#   '理性',
#   '预期',
#   '成人',
#   '见证',
#   '毁掉',
#   '好吃',
#   '养成',
#   '丰富',
#   '无忧',
#   '抱歉',
#   '怀着',
#   '借口',
#   '悲剧',
#   '渠道',
#   '分出',
#   '称职',
#   '走上',
#   '症状',
#   '安全',
#   '做人',
#   '代替',
#   '养到',
#   '捆绑',
#   '悲惨',
#   '扶养',
#   '出发',
#   '怀疑',
#   '全',
#   '出国',
#   '分离',
#   '走向',
#   '感恩',
#   '心力',
#   '换成',
#   '设想',
#   '人人',
#   '乖巧',
#   '分给',
#   '美食',
#   '当成',
#   '组建',
#   '期望',
#   '亲密',
#   '活成',
#   '填补',
#   '温暖',
#   '学到',
#   '窒息',
#   '屈服',
#   '容忍',
#   '舍弃',
#   '后者',
#   '支出',
#   '利己',
#   '物件',
#   '物资',
#   '看病',
#   '充斥',
#   '万难',
#   '庇护',
#   '用尽',
#   '力气',
#   '愉悦',
#   '心灵',
#   '劳动',
#   '正如',
#   '背叛',
#   '安静',
#   '总会',
#   '代沟',
#   '空话',
#   '歧视',
#   '直观',
#   '教会',
#   '空缺',
#   '增添',
#   '拮据',
#   '太重',
#   '毫无',
#   '品质',
#   '执念',
#   '惹事',
#   '担负',
#   '困惑',
#   '吵闹',
#   '到达',
#   '不满',
#   '画画',
#   '贬义',
#   '幼稚'],
#  0: ['小孩子', '不喜欢', '怕', '喜欢', '照顾', '妈妈', '情绪', '后悔', '可爱', '哭'],
#  3: ['不想',
#   '选择',
#   '爱',
#   '世界',
#   '负责',
#   '痛苦',
#   '生育',
#   '人生',
#   '带来',
#   '无法',
#   '幸福',
#   '我会',
#   '生命',
#   '责任',
#   '成为',
#   '认为',
#   '伤害',
#   '养育',
#   '个人',
#   '母亲',
#   '自由',
#   '接受',
#   '体验',
#   '承担',
#   '承受',
#   '不希望',
#   '不觉得',
#   '愿意',
#   '来到',
#   '遇到',
#   '准备',
#   '负担',
#   '恐惧',
#   '面对',
#   '不认为',
#   '带给',
#   '辛苦',
#   '做好',
#   '受罪',
#   '代价',
#   '不负责任',
#   '合格',
#   '资格',
#   '不合格'],
#  4: ['爸妈',
#   '家庭',
#   '事情',
#   '情况',
#   '思想',
#   '变成',
#   '麻烦',
#   '概率',
#   '经济',
#   '想到',
#   '想象',
#   '生不了',
#   '谈恋爱',
#   '开心',
#   '养不起',
#   '小',
#   '很大',
#   '怎么样',
#   '子女',
#   '难受',
#   '结果',
#   '估计',
#   '男性',
#   '骂',
#   '精神状态',
#   '羡慕',
#   '相信',
#   '夫妻',
#   '加上',
#   '一部分',
#   '崩溃',
#   '养儿防老',
#   '程度',
#   '时代',
#   '难过',
#   '人家',
#   '道理',
#   '大部分',
#   '道德',
#   '不算',
#   '单身',
#   '不考虑',
#   '观念',
#   '抑郁',
#   '为什么',
#   '意愿',
#   '不容易',
#   '不爱',
#   '感情',
#   '宠物',
#   '打死',
#   '老公',
#   '抱怨',
#   '严重',
#   '生完',
#   '投票',
#   '不婚',
#   '烦',
#   '就让',
#   '烦恼',
#   '留给',
#   '围着',
#   '饭',
#   '评论',
#   '接受不了',
#   '放在',
#   '拖累',
#   '说生',
#   '比如',
#   '回到',
#   '面临',
#   '后遗症',
#   '坚持',
#   '表现',
#   '狗狗',
#   '失败',
#   '游戏',
#   '交流',
#   '能生',
#   '劳动力',
#   '说不定',
#   '离开',
#   '遗传病',
#   '冲动',
#   '女友',
#   '佩服',
#   '不存在',
#   '小狗',
#   '来自',
#   '活该',
#   '养小孩',
#   '哈哈哈',
#   '抑郁症',
#   '恐怖',
#   '说白了',
#   '国家',
#   '惨',
#   '说出',
#   '同事',
#   '区别',
#   '委屈',
#   '讨论',
#   '意思',
#   '差不多',
#   '缺陷',
#   '不愿意',
#   '子宫',
#   '别生',
#   '完整',
#   '疼痛',
#   '弟',
#   '可怜',
#   '出来',
#   '异性恋',
#   '相亲',
#   '家境',
#   '大脑',
#   '就算',
#   '赡养',
#   '完成',
#   '头发',
#   '任务',
#   '内耗',
#   '生产',
#   'face',
#   '常态',
#   '繁衍',
#   '能养',
#   '心情',
#   '威逼利诱',
#   '退休金',
#   '巨大',
#   '打游戏',
#   '产后',
#   '矛盾',
#   '碰到',
#   '结束',
#   '人会',
#   '比例',
#   '嘲笑',
#   '所有人',
#   '久',
#   '还好',
#   '认知',
#   '爱情',
#   '没事',
#   '哭闹',
#   '谨慎',
#   '爽',
#   '降生',
#   '那句话',
#   '怕死',
#   '摆脱',
#   '不健康',
#   '维持',
#   '心理疾病',
#   '算了吧',
#   '答案',
#   '打工',
#   '潇洒',
#   '帮忙',
#   '建议',
#   '穷人',
#   '烦人',
#   '减少',
#   '吃苦',
#   '充满',
#   '试图',
#   '可悲',
#   '不得',
#   '好看',
#   '丈夫',
#   '地球',
#   '顾虑',
#   '外甥',
#   '头疼',
#   '本质',
#   '部分',
#   '放学',
#   '请问',
#   '人性',
#   '遭罪',
#   '生物',
#   '在意',
#   '伴随',
#   '主义者',
#   '人才',
#   '意见',
#   '影子',
#   '不接受',
#   '反应',
#   '音乐',
#   '犹豫',
#   '不自由',
#   '大人',
#   '不正常',
#   '受害者',
#   '加班',
#   '很烦',
#   '不止',
#   '母胎',
#   '不在乎',
#   '自找',
#   '害人',
#   '几十年',
#   '故事',
#   '懂事',
#   '通讯录',
#   '没耐心',
#   '管好',
#   '离谱',
#   '大学生',
#   '例子',
#   '悲观',
#   '阶级',
#   '鸡毛',
#   '可能性',
#   '财产',
#   '没问题',
#   '下水',
#   '无感',
#   '评价',
#   '对生',
#   '做梦',
#   '骨子里',
#   '活生生',
#   '留守',
#   '寻找',
#   '敏感',
#   '用来',
#   '管理',
#   '合适',
#   '保持',
#   '着想',
#   '说真的',
#   '婴儿',
#   '封建',
#   '婆媳关系',
#   '没本事',
#   '忍受',
#   '宝妈',
#   '变化',
#   '看法',
#   '坏',
#   '苦日子',
#   '义务',
#   '害',
#   '不生子',
#   '小猫咪',
#   '姐妹',
#   '幸运',
#   '超过',
#   '埋怨',
#   '都行',
#   '没关系',
#   '廉价',
#   '忍不住',
#   '耽误',
#   '渴望',
#   '总得',
#   '外卖',
#   '打扮',
#   '会长',
#   '宝贝',
#   '发达',
#   '漂亮',
#   '大出血',
#   '患上',
#   '玩意',
#   '批判',
#   '小事',
#   '满意',
#   '恢复',
#   '拖油瓶',
#   '富养',
#   '同情',
#   '幻想',
#   '家暴',
#   '高血压',
#   '嫌',
#   '体现',
#   '贵',
#   '不舒服',
#   '低于',
#   '开玩笑',
#   '职场',
#   '为难',
#   '角色',
#   '人口',
#   '养老院',
#   '先养',
#   '听话',
#   '穷养',
#   '没好',
#   '凑合',
#   '说明',
#   '烦躁',
#   '不清楚',
#   '公婆',
#   '家庭环境',
#   '发疯',
#   '选项',
#   '爷爷奶奶',
#   '躺平',
#   '事实',
#   '回去',
#   '绝大多数',
#   '提升',
#   '攻击',
#   '习惯',
#   '没人管',
#   '阴影',
#   '异性',
#   '人能',
#   '不靠',
#   '懂得',
#   '精神疾病',
#   '威胁',
#   '爷爷',
#   '放过',
#   '喂奶',
#   '亲戚家',
#   '拉扯',
#   '体质',
#   '医疗',
#   '天生',
#   '衣服',
#   '放心',
#   '目的',
#   '原生',
#   '同学',
#   '人士',
#   '来讲',
#   '看过',
#   '责任心',
#   '过日子',
#   '偏向',
#   '开明',
#   '注意',
#   '天性',
#   '只生',
#   '要钱',
#   '贡献',
#   '很痛',
#   '满',
#   '睡',
#   '出轨',
#   '拼搏',
#   '应得',
#   '领',
#   '软肋',
#   '智慧',
#   '劣质',
#   '我爸',
#   '在乎',
#   '容易',
#   '财富',
#   '反驳',
#   '伴',
#   '氛围',
#   '升职',
#   '对比',
#   '真',
#   '选错',
#   '温饱',
#   '资助',
#   '排除',
#   '信任',
#   '觉悟',
#   '太小',
#   '弱',
#   '比养',
#   '丢掉',
#   '复刻',
#   '很小',
#   '组成',
#   '干预',
#   '代孕',
#   '沉默',
#   '粗',
#   '中心',
#   '儿女',
#   '网友',
#   '抢',
#   '冷汗',
#   '原谅',
#   '睡觉',
#   '物种',
#   '换来',
#   '闭嘴',
#   '劝生',
#   '背着',
#   '睡着',
#   '疯狂',
#   '不该',
#   '压根',
#   '吓',
#   '好像',
#   '攒够',
#   '遭受',
#   '商量',
#   '失业',
#   '人品',
#   '矫情',
#   '经营',
#   '口子',
#   '障碍',
#   '营造',
#   '闹',
#   '问问',
#   '放松',
#   '赌博',
#   '出路',
#   '相反',
#   '用品',
#   '总结',
#   '恨',
#   '兴趣',
#   '概念',
#   '小病',
#   '胃病',
#   '意外',
#   '太卷',
#   '放假',
#   '压迫',
#   '成功',
#   '调整',
#   '社交',
#   '法律',
#   '掐死',
#   '增加',
#   '小时',
#   '平庸',
#   '拘束',
#   '费',
#   '专业',
#   '舒服',
#   '天使',
#   '检查',
#   '鸡',
#   '搞笑',
#   '排斥',
#   '代表',
#   '举例',
#   '带上',
#   '进入',
#   '心想',
#   '倒霉',
#   '循环',
#   '危险',
#   '实在',
#   '恐',
#   '单亲',
#   '活法',
#   '阶段',
#   '发愁',
#   '洗脑',
#   '起码',
#   '纯纯',
#   '完事',
#   '理念',
#   '考研',
#   '优质',
#   '时光',
#   '活好',
#   '没养',
#   '怀胎',
#   '愧疚',
#   '煎熬',
#   '吃屎',
#   '攀比',
#   '养人',
#   '步入',
#   '学业',
#   '岗位',
#   '相比',
#   '手术',
#   '胎儿',
#   '血脉',
#   '慎重',
#   '剥削',
#   '智商',
#   '溺爱',
#   '哄',
#   '性欲',
#   '兽性',
#   '和谐',
#   '远',
#   '否定',
#   '钱包',
#   '奢求',
#   '土地',
#   '血缘',
#   '主人',
#   '耗费',
#   '尝试',
#   '数量',
#   '担忧',
#   '亲生',
#   '发火',
#   '克制',
#   '关心',
#   '命运',
#   '发呆',
#   '治病',
#   '外地',
#   '纯粹',
#   '损失',
#   '注定',
#   '反思',
#   '维系',
#   '存',
#   '不吃',
#   '难看',
#   '生卷',
#   '大哥',
#   '吃饱',
#   '嚷嚷',
#   '学生',
#   '复杂',
#   '乖',
#   '脖子',
#   '热度',
#   '奇怪',
#   '哥',
#   '获得',
#   '消费',
#   '靠',
#   '再养',
#   '二婚',
#   '白',
#   '沒有',
#   '提高',
#   '討厭',
#   '编制',
#   '拴住',
#   '凄惨',
#   '叛逆',
#   '老太',
#   '人们',
#   '争吵',
#   '大量',
#   '双向',
#   '爱护',
#   '乐器',
#   '薪水',
#   '子孙',
#   '醒来',
#   '就业',
#   '屁娃',
#   '孙儿',
#   '小说',
#   '修行',
#   '眼睛',
#   '唠嗑',
#   '执着',
#   '纳税',
#   '受尽',
#   '定义',
#   '模式',
#   '父辈',
#   '月经',
#   '小姨',
#   '庄稼',
#   '位置',
#   '背景',
#   '殴打',
#   '孤僻',
#   '媳妇',
#   '淹没',
#   '试管',
#   '迁怒',
#   '嫌弃',
#   '慌',
#   '抛弃',
#   '进行',
#   '疼爱',
#   '老实',
#   '爱心',
#   '虐待',
#   '遗产',
#   '模样',
#   '打骂',
#   '明显',
#   '看护',
#   '友情',
#   '补贴',
#   '老二',
#   '思维',
#   '剥夺',
#   '层面',
#   '引产',
#   '受过',
#   '闯入',
#   '狭隘',
#   '说教',
#   '休息',
#   '喜悦',
#   '贬低',
#   '突发',
#   '老头',
#   '参加',
#   '处境',
#   '忘记',
#   '基础',
#   '方便',
#   '后盾',
#   '规则',
#   '实习',
#   '不闹',
#   '不适',
#   '重度',
#   '毒打',
#   '佛系',
#   '消磨',
#   '琐事',
#   '套子',
#   '嫉妒',
#   '小钱',
#   '不孝',
#   '判断',
#   '和睦',
#   '不知',
#   '没错',
#   '辍学',
#   '出钱',
#   '时期',
#   '欢迎',
#   '霍霍',
#   '配偶',
#   '使命',
#   '成就',
#   '积累',
#   '馒头',
#   '注重',
#   '裙子',
#   '分享',
#   '厂里',
#   '美满',
#   '尖叫',
#   '项目',
#   '活力',
#   '团圆',
#   '消息',
#   '无效',
#   '激素',
#   '渣子',
#   '鼻炎',
#   '殆尽',
#   '未婚',
#   '具体',
#   '熬过',
#   '叠满',
#   '反抗',
#   '儿童',
#   '不易',
#   '念书',
#   '张嘴',
#   '觉醒',
#   '爱玩',
#   '模仿',
#   '疲惫',
#   '怜悯',
#   '结合',
#   '踏进',
#   '死活',
#   '克服',
#   '县城',
#   '劝退',
#   '训练',
#   '手机',
#   '惜命',
#   '遭遇',
#   '富人',
#   '劝解',
#   '事件',
#   '准则',
#   '方法',
#   '凄凉',
#   '声音',
#   '创伤',
#   '倾诉',
#   '农村',
#   '无限',
#   '感想',
#   '差距',
#   '上课',
#   '恐育',
#   '后腿',
#   '经验',
#   '科技',
#   '勇气',
#   '婆婆',
#   '瘦',
#   '渡过',
#   '健身',
#   '劳累',
#   '语文',
#   '性质',
#   '照看',
#   '纽带',
#   '在于',
#   '二老',
#   '無法',
#   '地区',
#   '支撐',
#   '麻煩',
#   '私心',
#   '打破',
#   '规律',
#   '见到',
#   '抉择',
#   '煽动',
#   '差异',
#   '男丁',
#   '死亡',
#   '母性',
#   '接触',
#   '流泪',
#   '时刻',
#   '世俗',
#   '文化',
#   '抛开',
#   '动力',
#   '人民',
#   '众生',
#   '苦短',
#   '肚皮',
#   '枷锁',
#   '个子',
#   '爆发',
#   '浪费',
#   '围绕',
#   '事太',
#   '厕所',
#   '攻略',
#   '步骤',
#   '圆满',
#   '桎梏',
#   '生理',
#   '物业',
#   '了生',
#   '短暂',
#   '腰疼',
#   '总能',
#   '男方',
#   '深切',
#   '再婚',
#   '更累',
#   '床上',
#   '收拾',
#   '咋办',
#   '超出',
#   '巴掌',
#   '责骂',
#   '说法',
#   '奉献',
#   '剔除',
#   '双相',
#   '扶持',
#   '尿管',
#   '想起',
#   '手脚',
#   '恶露',
#   '狂魔',
#   '地狱',
#   '典型',
#   '勇敢',
#   '喝水',
#   '描述',
#   '被动',
#   '植物',
#   '有着',
#   '机车',
#   '做饭',
#   '放下',
#   '生意',
#   '生计',
#   '送走',
#   '杠杆',
#   '歹毒',
#   '挣得',
#   '恐慌',
#   '地步',
#   '释怀',
#   '作用',
#   '不均',
#   '育儿',
#   '认可',
#   '生怕',
#   '住院',
#   '撕裂',
#   '自责',
#   '集中',
#   '徒增',
#   '着急',
#   '内疚',
#   '询问',
#   '依靠',
#   '婆家',
#   '伸手',
#   '聊到',
#   '宽裕',
#   '电视',
#   '歪路',
#   '心累',
#   '太贵',
#   '缺少',
#   '不可',
#   '厌倦',
#   '孕吐',
#   '理想',
#   '力量',
#   '理财',
#   '行业',
#   '乐意',
#   '讽刺',
#   '考上',
#   '费用',
#   '无痛',
#   '反感',
#   '损耗',
#   '糟心',
#   '母体',
#   '姥姥',
#   '可靠',
#   '留在',
#   '老伴',
#   '帮扶',
#   '极大',
#   '跟随',
#   '回答',
#   '小丑',
#   '意向',
#   '好感',
#   '看似',
#   '环节',
#   '还生',
#   '收获',
#   '不安',
#   '亏待',
#   '缺失',
#   '逛街',
#   '电影',
#   '懒',
#   '离异',
#   '活泼',
#   '好人',
#   '传给',
#   '奔波',
#   '不留',
#   '发怒',
#   '新人',
#   '态度',
#   '看作',
#   '诈骗',
#   '干活',
#   '调皮',
#   '笃定',
#   '认同',
#   '分娩',
#   '费钱',
#   '学费',
#   '争取',
#   '投射'],
#  1: ['钱',
#   '结婚',
#   '多',
#   '问题',
#   '穷',
#   '有孩子',
#   '还有',
#   '养孩子',
#   '只能',
#   '压力',
#   '养老',
#   '继承',
#   '精力',
#   '差',
#   '发现',
#   '累',
#   '不行',
#   '活着',
#   '难',
#   '养猫',
#   '催',
#   '成本',
#   '不用',
#   '猫',
#   '稳定',
#   '买',
#   '长',
#   '高',
#   '狗',
#   '样子',
#   '养活',
#   '关系',
#   '病',
#   '对象',
#   '不错',
#   '享受',
#   '想着',
#   '没什么',
#   '焦虑',
#   '养狗',
#   '生病',
#   '赌',
#   '婚',
#   '工资',
#   '年轻',
#   '方式',
#   '儿孙',
#   '赚',
#   '收入',
#   '上班',
#   '老人',
#   '到时候',
#   '想养',
#   '不养',
#   '出去',
#   '操心',
#   '旅游',
#   '卷',
#   '读书',
#   '牺牲',
#   '低',
#   '牛马',
#   '年轻人',
#   '发展',
#   '费劲',
#   '方面',
#   '回报',
#   '存款',
#   '日子',
#   '找到',
#   '事业',
#   '没时间',
#   '幼儿园',
#   '毕业',
#   '学校',
#   '命',
#   '享福',
#   '上学',
#   '奶粉',
#   '买房',
#   '出去玩',
#   '开销',
#   '儿孙自有',
#   '要小孩',
#   '不需要',
#   '规划',
#   '投资',
#   '高考',
#   '关爱',
#   '花费',
#   '小猫',
#   '屎',
#   '好不好',
#   '退休',
#   '花销',
#   '奋斗',
#   '生活费',
#   '教育资源',
#   '计划',
#   '补习班',
#   '家务',
#   '大病',
#   '作业',
#   '吃饭',
#   '念头',
#   '酒店',
#   '旅行',
#   '看不到',
#   '独生子女',
#   '双休',
#   '养家',
#   '暴力',
#   '贷款',
#   '玩具',
#   '放贷',
#   '打消',
#   '保险',
#   '辅导'],
#  8: ['我妈',
#   '时候',
#   '不知道',
#   '爸爸',
#   '原因',
#   '想法',
#   '看到',
#   '苦',
#   '丁克',
#   '开始',
#   '应该',
#   '尊重',
#   '理解',
#   '不结婚',
#   '吃',
#   '大家',
#   '逼',
#   '劝',
#   '视频',
#   '家',
#   '女性',
#   '有没有',
#   '观点',
#   '怀孕',
#   '朋友',
#   '要生',
#   '看着',
#   '导致',
#   '折磨',
#   '玩',
#   '不婚不育',
#   '弟弟',
#   '对方',
#   '绑架',
#   '快',
#   '祝福',
#   '回家',
#   '不同',
#   '儿子',
#   '了解',
#   '痛',
#   '家里人',
#   '不理解',
#   '医院',
#   '少',
#   '年龄',
#   '独立',
#   '大学',
#   '老婆',
#   '说实话',
#   '生出',
#   '家人',
#   '共情',
#   '想生',
#   '姐姐',
#   '疼',
#   '男朋友',
#   '看见',
#   '继续',
#   '坚定',
#   '离婚',
#   '再生',
#   '轻松',
#   '笑',
#   '不到',
#   '听到',
#   '不懂',
#   '要不要',
#   '一个月',
#   '肚子',
#   '包括',
#   '吵架',
#   '传宗接代',
#   '出现',
#   '记得',
#   '保护',
#   '话题',
#   '不一样',
#   '亲戚',
#   '医生',
#   '好事',
#   '奶奶',
#   '安慰',
#   '大多数',
#   '孙子',
#   '骗',
#   '性别',
#   '香火',
#   '传统',
#   '地方',
#   '生二胎',
#   '逼迫',
#   '卖',
#   '事儿',
#   '小学',
#   '发生',
#   '嫁',
#   '欺负',
#   '挣钱',
#   '农民',
#   '生女孩',
#   '震惊',
#   '百分之',
#   '跑',
#   '全家',
#   '几率',
#   '屁事',
#   '没用',
#   '皮肤',
#   '辞职',
#   '分手',
#   '妊娠',
#   '表达',
#   '确诊',
#   '现象',
#   '网络',
#   '知识',
#   '催生',
#   '生宝宝',
#   '营养',
#   '送到',
#   '彩礼',
#   '兄弟',
#   '纠结',
#   '不同意',
#   '后妈',
#   '缺乏',
#   '谢谢',
#   '吓人',
#   '回来',
#   '吃药',
#   '弹幕',
#   '统计',
#   '妹妹',
#   '最小',
#   '男女',
#   '心疼',
#   '查出',
#   '答应',
#   '不明白',
#   '陌生',
#   '发表',
#   '疤',
#   '顺产',
#   '听说',
#   '心动',
#   '转变',
#   '怀',
#   '妻子',
#   '赞同',
#   '外婆',
#   '刷到',
#   '省心',
#   '灌输',
#   '人流',
#   '地位',
#   '孙女',
#   '要养',
#   '祖宗',
#   '强制',
#   '关键',
#   '弱点',
#   '长胖',
#   '孤立',
#   '作何',
#   '样貌',
#   '鉴定',
#   '标本',
#   '法院',
#   '群体',
#   '出门',
#   '平台',
#   '明星',
#   '打架',
#   '遇上'],
#  6: ['工作', '车与房', '老', '怎么办', '老师', '找不到'],
#  7: ['男人', '女人', '男孩', '女孩', '女儿', '重男轻女'],
#  5: ['下辈子',
#   '太好了',
#   '诅咒',
#   '哈哈哈哈',
#   '找对象',
#   '已婚',
#   '权衡利弊',
#   '黄',
#   '养不了',
#   '调生',
#   '有罪',
#   '扭曲',
#   '表扬',
#   '條件',
#   '自信',
#   '生孩',
#   '反问',
#   '想来',
#   '坏处',
#   '怕生',
#   '厉害',
#   '领证',
#   '苍老',
#   '錢',
#   '已育',
#   '主义',
#   '数据',
#   '灵活',
#   '玩家',
#   '规定',
#   '过敏',
#   '差劲',
#   '删掉',
#   '探讨',
#   '有利',
#   '愤怒',
#   '看白',
#   '面子',
#   '筹划',
#   '根本',
#   '罪人',
#   '费力',
#   '女方',
#   '灭绝',
#   '开局',
#   '现状',
#   '背负',
#   '养娃',
#   '招罪',
#   '出于',
#   '无趣',
#   '漩涡',
#   '充沛',
#   '求求',
#   '家長',
#   '拼命',
#   '懒得',
#   '阻止',
#   '叨叨',
#   '上线',
#   '偏差',
#   '鬼话',
#   '得生',
#   '教给',
#   '稀烂',
#   '主打',
#   '破事',
#   '难听',
#   '自豪',
#   '再选',
#   '掂量',
#   '告别',
#   '月薪',
#   '观看',
#   '快递',
#   '鄙视',
#   '卑微',
#   '深陷',
#   '回避',
#   '本性',
#   '流产',
#   '亏欠',
#   '笔记',
#   '辱骂',
#   '强迫',
#   '受累',
#   '记忆',
#   '扎心',
#   '姨妈',
#   '养花',
#   '尘埃',
#   '少果',
#   '好坏',
#   '嗓子',
#   '眼光',
#   '够买',
#   '苦恼',
#   '基',
#   '开头',
#   '鸡娃',
#   '客观',
#   '傲慢',
#   '乐',
#   '拉低',
#   '强烈',
#   '三思',
#   '高赞',
#   '逻辑',
#   '好奇',
#   '裹挟',
#   '隔断',
#   '好运',
#   '遗体',
#   '浑水',
#   '同理',
#   '不育',
#   '盲盒',
#   '抓住',
#   '做主',
#   '投胎',
#   '婚育',
#   '宣扬',
#   '硬生',
#   '爱生',
#   '能选',
#   '收养',
#   '思潮',
#   '宽',
#   '苦痛',
#   '累死',
#   '对立',
#   '高铁',
#   '放开',
#   '对面',
#   '零食',
#   '把柄',
#   '反击',
#   '筛选',
#   '养死',
#   '例如',
#   '说服',
#   '新闻',
#   '妥协',
#   '对抗',
#   '累赘',
#   '类似',
#   '逍遥',
#   '连猫',
#   '直女',
#   '流量',
#   '恐婚',
#   '惦记',
#   '规避',
#   '放過',
#   '選擇',
#   '毁灭',
#   '安定',
#   '终老',
#   '素质',
#   '主義',
#   '上受',
#   '点错',
#   '符合',
#   '相爱',
#   '平衡',
#   '公平']}
