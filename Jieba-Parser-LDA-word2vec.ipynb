# %% [markdown]
# # Fertility Comment LDA Pipeline
#
# This notebook is a thin wrapper around the Python modules:
# - `preprocess_corpus.py` — ingestion, cleaning, dictionary/corpus construction
# - `lda_utils.py` — TF-IDF + LDA training and topic summaries
# - `main.py` — orchestration and configuration
#
# Edit paths and hyper-parameters in `main.py`.

# %%
from main import main

if __name__ == "__main__":
    results = main()
